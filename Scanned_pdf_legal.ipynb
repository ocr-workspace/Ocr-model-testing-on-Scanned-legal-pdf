# %% [markdown]
# <a href="https://colab.research.google.com/github/ocr-workspace/Ocr-model-testing-on-Scanned-legal-pdf/blob/main/Scanned_pdf_legal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers accelerate bitsandbytes qwen-vl-utils evaluate datasets jiwer

# %%
# !pip install datasets evaluate pdf2image pytesseract  doctr transformers

# %% [markdown]
# **Dataset Loading**

# %%
from datasets import load_dataset

ds_legal = load_dataset("nielsr/funsd")

print(ds_legal)

# %% [markdown]
# **Ground Truth Builder Function**

# %%
def build_gt_funsd(sample):
    words = sample["words"]
    text = " ".join(words)
    return text.strip()

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# **Evalaution Matrix Setup**

# %%
# !pip install jiwer

# %%
import evaluate
import numpy as np
import time
import pandas as pd

cer_metric = evaluate.load("cer")
wer_metric = evaluate.load("wer")

# %% [markdown]
# **Runner Function**

# %%
import time
import cv2
from PIL import Image
import pandas as pd
import numpy as np
def benchmark_legal(ds, ocr_function, model_name, samples=50):

    results = []

    for i in range(samples):

        sample = ds["train"][i]
        image = sample["image"]
        gt_text = build_gt_funsd(sample)

        start = time.time()
        pred_text = ocr_function(image)
        end = time.time()

        cer = cer_metric.compute(
            predictions=[pred_text],
            references=[gt_text]
        )

        wer = wer_metric.compute(
            predictions=[pred_text],
            references=[gt_text]
        )

        word_dev = abs(
            len(pred_text.split()) - len(gt_text.split())
        )

        results.append({
            "CER": cer,
            "WER": wer,
            "Word_Count_Deviation": word_dev,
            "Time": end - start
        })

    df = pd.DataFrame(results)

    print(f"\n===== {model_name} (Legal OCR) =====")
    print("Mean CER:", df["CER"].mean())
    print("Mean WER:", df["WER"].mean())
    print("Avg Word Count Deviation:", df["Word_Count_Deviation"].mean())
    print("Avg Time:", df["Time"].mean())

    return df

# %% [markdown]
# **Tesseract Function**

# %%
# !apt-get install -y tesseract-ocr
# !pip install pytesseract

# %%
import pytesseract

def tesseract_ocr(image):

    if isinstance(image, Image.Image):
        image = np.array(image)

    text = pytesseract.image_to_string(image)
    return text.strip()

# %% [markdown]
# **Paddle Ocr **

# %%
# !pip install paddlepaddle-gpu

# %%
# Force-uninstall the broken numpy
# !pip uninstall numpy -y

# Install the packages but strictly lock numpy at 1.26.4 simultaneously
# !pip install numpy==1.26.4 paddleocr==2.8.1 evaluate doctr

# %%
# Uninstall langchain to bypass the PaddleX import bug
# This will NOT touch your numpy or paddlepaddle installations!
# !pip uninstall langchain langchain-community langchain-core -y

# %% [markdown]
# **Model Loading**

# %%
# !pip list | grep -E "numpy|paddle|evaluate"
# Out:
# evaluate                                 0.4.6
# numpy                                    1.26.4
# paddleocr                                2.8.1
# paddlepaddle-gpu                         2.6.2

# %%
from paddleocr import PaddleOCR

paddle_model = PaddleOCR(
    use_angle_cls=True,
    lang='en',
    use_gpu=True
)

# %% [markdown]
# Function

# %%
def paddle_ocr(image):

    if isinstance(image, Image.Image):
        image = np.array(image)

    result = paddle_model.ocr(image)

    text = ""
    for line in result:
        for word_info in line:
            text += word_info[1][0] + " "

    return text.strip()

# %% [markdown]
# **DocTR**

# %% [markdown]
# Model Loading

# %%
 # !pip install python-doctr

# %%
from doctr.models import ocr_predictor
import torch

# 1. Dynamically check for a GPU (CUDA). If not found, use the CPU.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Loading model onto: {device}")

# 2. Load the docTR model and send it to the chosen device
doctr_model = ocr_predictor(pretrained=True).to(device)

print("docTR model loaded successfully!")
# Out:
# Loading model onto: cuda
# docTR model loaded successfully!

# %% [markdown]
# * Function

# %%
def doctr_ocr(image):

    if isinstance(image, Image.Image):
        image = np.array(image)

    if len(image.shape) == 2:
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

    result = doctr_model([image])

    text = ""
    for page in result.pages:
        for block in page.blocks:
            for line in block.lines:
                for word in line.words:
                    text += word.value + " "

    return text.strip()

# %% [markdown]
# **Hybrid (Paddle Detection + TrOCR Recognition)**

# %%
# !pip install transformers

# %% [markdown]
# * Load TrOCR (Printed)

# %%
from transformers import TrOCRProcessor, VisionEncoderDecoderModel

processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-printed")
model_trocr = VisionEncoderDecoderModel.from_pretrained(
    "microsoft/trocr-base-printed"
).to(device)

# %% [markdown]
# * Hybrid Function

# %%
def hybrid_ocr(image):

    if isinstance(image, Image.Image):
        image = np.array(image)

    result = paddle_model.ocr(image)

    boxes = []
    for line in result:
        for word_info in line:
            boxes.append(word_info[0])

    boxes = sorted(boxes, key=lambda x: (x[0][1], x[0][0]))

    recognized_words = []

    for box in boxes:

        pts = np.array(box).astype(int)

        x_min = max(0, min(pts[:,0]))
        y_min = max(0, min(pts[:,1]))
        x_max = max(0, max(pts[:,0]))
        y_max = max(0, max(pts[:,1]))

        crop = image[y_min:y_max, x_min:x_max]

        if crop.size == 0:
            continue

        #  VERY IMPORTANT FIX
        if len(crop.shape) == 2:
            crop = cv2.cvtColor(crop, cv2.COLOR_GRAY2RGB)
        elif crop.shape[2] == 4:
            crop = cv2.cvtColor(crop, cv2.COLOR_RGBA2RGB)

        crop = cv2.resize(crop, None, fx=2, fy=2)

        # Convert to PIL (TrOCR prefers PIL)
        crop_pil = Image.fromarray(crop)

        pixel_values = processor(
            images=crop_pil,
            return_tensors="pt"
        ).pixel_values.to(device)

        generated_ids = model_trocr.generate(pixel_values)

        text = processor.batch_decode(
            generated_ids,
            skip_special_tokens=True
        )[0]

        recognized_words.append(text)

    return " ".join(recognized_words)

# %%
df_tess = benchmark_legal(ds_legal, tesseract_ocr, "Tesseract")
# Out:
# ===== Tesseract (Legal OCR) =====
# Mean CER: 0.5772690521505756
# Mean WER: 0.7157845192522629
# Avg Word Count Deviation: 18.56
# Avg Time: 0.884716830253601

# %%
df_paddle = benchmark_legal(ds_legal, paddle_ocr, "PaddleOCR")
# Out:
# [2026/02/26 04:32:39] ppocr DEBUG: dt_boxes num : 29, elapsed : 0.9679949283599854
# [2026/02/26 04:32:39] ppocr DEBUG: cls num  : 29, elapsed : 0.16066360473632812
# [2026/02/26 04:32:39] ppocr DEBUG: rec_res num  : 29, elapsed : 0.2750120162963867
# [2026/02/26 04:32:39] ppocr DEBUG: dt_boxes num : 113, elapsed : 0.07697701454162598
# [2026/02/26 04:32:40] ppocr DEBUG: cls num  : 113, elapsed : 0.3188467025756836
# [2026/02/26 04:32:40] ppocr DEBUG: rec_res num  : 113, elapsed : 0.32578086853027344
# [2026/02/26 04:32:40] ppocr DEBUG: dt_boxes num : 42, elapsed : 0.046300411224365234
# [2026/02/26 04:32:40] ppocr DEBUG: cls num  : 42, elapsed : 0.05474567413330078
# [2026/02/26 04:32:40] ppocr DEBUG: rec_res num  : 42, elapsed : 0.1426393985748291
# [2026/02/26 04:32:41] ppocr DEBUG: dt_boxes num : 150, elapsed : 0.08202791213989258
# [2026/02/26 04:32:41] ppocr DEBUG: cls num  : 150, elapsed : 0.19369125366210938
# ...

# %%
df_doctr = benchmark_legal(ds_legal, doctr_ocr, "DocTR")
# Out:
# ===== DocTR (Legal OCR) =====
# Mean CER: 0.4750372750721484
# Mean WER: 0.6198433987584714
# Avg Word Count Deviation: 10.38
# Avg Time: 0.29754053115844725

# %%
df_hybrid = benchmark_legal(ds_legal, hybrid_ocr, "Hybrid")
# Out:
# [2026/02/26 04:46:48] ppocr DEBUG: dt_boxes num : 29, elapsed : 0.05209517478942871
# [2026/02/26 04:46:49] ppocr DEBUG: cls num  : 29, elapsed : 0.23719406127929688
# [2026/02/26 04:46:49] ppocr DEBUG: rec_res num  : 29, elapsed : 0.16016411781311035
# [2026/02/26 04:46:55] ppocr DEBUG: dt_boxes num : 113, elapsed : 0.0753326416015625
# [2026/02/26 04:46:56] ppocr DEBUG: cls num  : 113, elapsed : 0.14495444297790527
# [2026/02/26 04:46:56] ppocr DEBUG: rec_res num  : 113, elapsed : 0.3207263946533203
# [2026/02/26 04:47:08] ppocr DEBUG: dt_boxes num : 42, elapsed : 0.045534610748291016
# [2026/02/26 04:47:08] ppocr DEBUG: cls num  : 42, elapsed : 0.0556187629699707
# [2026/02/26 04:47:09] ppocr DEBUG: rec_res num  : 42, elapsed : 0.14213156700134277
# [2026/02/26 04:47:14] ppocr DEBUG: dt_boxes num : 150, elapsed : 0.07756328582763672
# [2026/02/26 04:47:14] ppocr DEBUG: cls num  : 150, elapsed : 0.1912078857421875
# ...

# %% [markdown]
# **Florence -2 testing **

# %%
# !pip install -q einops timm

# %% [markdown]
# **Model Intialization**

# %%
import torch
from transformers import AutoProcessor, Florence2ForConditionalGeneration

print("Loading Florence-2-Large (Native Hugging Face Port)...")

# 1. Load the Model and Processor cleanly
model_id = "florence-community/Florence-2-large"
model = Florence2ForConditionalGeneration.from_pretrained(
    model_id,
    torch_dtype=torch.float16
).to("cuda")

processor = AutoProcessor.from_pretrained(model_id)
model.eval()

print("✅ Florence-2 Loaded Successfully!")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading Florence-2-Large (Native Hugging Face Port)...
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.55G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/917 [00:00<?, ?it/s]
# Florence2ForConditionalGeneration LOAD REPORT from: florence-community/Florence-2-large
# Key            | Status  |
# ---------------+---------+-
# lm_head.weight | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# generation_config.json:   0%|          | 0.00/292 [00:00<?, ?B/s]
# processor_config.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/603 [00:00<?, ?B/s]
# ...

# %% [markdown]
# Florence Wrapper Func

# %%
# 2. Define the Wrapper Function for your benchmark loop
def florence2_legal_ocr(image):
    """
    Takes a PIL Image of a legal document and returns transcribed text using Florence-2.
    Matches the input/output signature of pytesseract_ocr and doctr_ocr.
    """
    if image.mode != "RGB":
        image = image.convert("RGB")

    # We use pure <OCR> to output a flat string for fair CER/WER comparison
    task_prompt = "<OCR>"

    # Process inputs
    inputs = processor(text=task_prompt, images=image, return_tensors="pt").to("cuda", torch.float16)

    # Generate Output
    with torch.no_grad():
        generated_ids = model.generate(
            input_ids=inputs["input_ids"],
            pixel_values=inputs["pixel_values"],
            max_new_tokens=2048, # INCREASED: Legal documents are very dense!
            early_stopping=False,
            do_sample=False,
            num_beams=3,
        )

    # Decode and parse
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=False)[0]
    parsed_answer = processor.post_process_generation(
        generated_text,
        task=task_prompt,
        image_size=(image.width, image.height)
    )

    return parsed_answer["<OCR>"].strip()

# %%
print("\nEvaluating Florence-2 on Scanned Legal Documents...")
benchmark_legal(ds_legal, florence2_legal_ocr, "Florence-2 Legal", samples=20)
# Out:
# Evaluating Florence-2 on Scanned Legal Documents...
#
# ===== Florence-2 Legal (Legal OCR) =====
# Mean CER: 12.668477539430402
# Mean WER: 9.412867386896616
# Avg Word Count Deviation: 1229.35
# Avg Time: 40.099512052536014
#           CER        WER  Word_Count_Deviation       Time
# 0   11.080544   9.641379                  1253  38.768057
# 1    7.588480   6.426724                  1259  39.050605
# 2   14.822254  10.151515                  1208  38.629116
# 3    6.479167   4.535593                  1045  39.263036
# 4   23.357741  15.233333                  1281  38.704440
# 5    9.022970   8.216931                  1364  52.767087
# 6    8.064649   6.217213                  1273  38.469455
# 7   13.500000   9.393103                  1217  44.337839
# 8   14.373096  12.037594                  1468  40.429139
# 9   14.124493   9.055556                  1160  39.238762
# 10  10.847689   7.455090                  1079  38.905346
# ...

# %% [markdown]
# **Qwen2-VL**

# %%
! pip uninstall -y transformers
! pip install transformers accelerate bitsandbytes

# %% [markdown]
# **Model Initiallization**

# %%
import torch
from transformers import Qwen2VLForConditionalGeneration, AutoProcessor, BitsAndBytesConfig
from qwen_vl_utils import process_vision_info

print("Loading Qwen2-VL-7B (4-bit)...")

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

model_id = "Qwen/Qwen2-VL-7B-Instruct"

model = Qwen2VLForConditionalGeneration.from_pretrained(
    model_id,
    device_map="auto",
    quantization_config=quantization_config
)

processor = AutoProcessor.from_pretrained(model_id)
model.eval()

print("✅ Qwen2-VL Loaded Successfully!")

# %% [markdown]
# **Qwen Wrapper Func**

# %%
from PIL import Image
import numpy as np

def qwen_legal_ocr(image):
    # Ensure image is in PIL format
    if isinstance(image, np.ndarray):
        image = Image.fromarray(image)

    if image.mode != "RGB":
        image = image.convert("RGB")

    # Strict prompt to prevent conversational hallucination
    system_prompt = "You are a highly accurate legal document transcription system. Transcribe all the text in this document exactly as it appears. Output ONLY the transcribed text. Do not add markdown, formatting, or conversational filler."

    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image", "image": image},
                {"type": "text", "text": system_prompt},
            ]
        }
    ]

    text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    image_inputs, video_inputs = process_vision_info(messages)

    inputs = processor(
        text=[text],
        images=image_inputs,
        videos=video_inputs,
        padding=True,
        return_tensors="pt",
    ).to("cuda")

    with torch.no_grad():
        generated_ids = model.generate(
            **inputs,
            max_new_tokens=2048, # Massive token limit for dense legal pages
            temperature=0.1,
            do_sample=False
        )

    generated_ids_trimmed = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
    ]
    response = processor.batch_decode(generated_ids_trimmed, skip_special_tokens=True)[0]

    return response.strip()

# %%
print("\nEvaluating Qwen2-VL on Scanned Legal Documents...")
df_qwen = benchmark_legal(ds_legal, qwen_legal_ocr, "Qwen2-VL Legal", samples=50)
# Out:
# Evaluating Qwen2-VL on Scanned Legal Documents...
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ===== Qwen2-VL Legal (Legal OCR) =====
# Mean CER: 0.6545362482151699
# Mean WER: 0.8237109541782103
# Avg Word Count Deviation: 61.7
# Avg Time: 34.438241720199585

# %% [markdown]
# olmOcr Model

# %%
import torch
from transformers import AutoProcessor, Qwen2VLForConditionalGeneration, BitsAndBytesConfig
from qwen_vl_utils import process_vision_info

print("Loading olmOCR (AI2's Document OCR Specialist)...")

model_id = "allenai/olmOCR-7B-0225-preview"

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

model = Qwen2VLForConditionalGeneration.from_pretrained(
    model_id,
    device_map="auto",
    quantization_config=quantization_config
)

processor = AutoProcessor.from_pretrained(model_id)
model.eval()

print("✅ olmOCR Loaded Successfully!")

# %%
from PIL import Image
import numpy as np

def olmocr_legal_ocr(image):
    if isinstance(image, np.ndarray):
        image = Image.fromarray(image)

    if image.mode != "RGB":
        image = image.convert("RGB")

    # olmOCR is heavily fine-tuned, so a simple extraction prompt is all it needs
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image", "image": image},
                {"type": "text", "text": "Extract the text from this document."},
            ]
        }
    ]

    text = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
    image_inputs, video_inputs = process_vision_info(messages)

    inputs = processor(
        text=[text],
        images=image_inputs,
        videos=video_inputs,
        padding=True,
        return_tensors="pt",
    ).to("cuda")

    with torch.no_grad():
        generated_ids = model.generate(
            **inputs,
            max_new_tokens=2048, # High limit for dense legal pages
            temperature=0.1,
            do_sample=False
        )

    generated_ids_trimmed = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
    ]
    response = processor.batch_decode(generated_ids_trimmed, skip_special_tokens=True)[0]

    return response.strip()

# %%
("\nEvaluating olmOCR on Scanned Legal Documents...")
df_olmocr = benchmark_legal(ds_legal, olmocr_legal_ocr, "olmOCR Legal", samples=20)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ===== olmOCR Legal (Legal OCR) =====
# Mean CER: 0.9013618939080962
# Mean WER: 0.8079600446093395
# Avg Word Count Deviation: 37.45
# Avg Time: 45.58526434898376

# %% [markdown]
# **Nougat testing**

# %%
import json
import os
import torch
from huggingface_hub import snapshot_download
from transformers import NougatProcessor, VisionEncoderDecoderModel

print("Downloading and physically patching Nougat's config file...")

model_id = "facebook/nougat-base"
local_dir = "./nougat-base-patched"

# 1. Download the repository locally (this is instant if you already downloaded the weights earlier)
snapshot_download(repo_id=model_id, local_dir=local_dir)

# 2. Open the offending preprocessor config file
config_path = os.path.join(local_dir, "preprocessor_config.json")
with open(config_path, "r") as f:
    config = json.load(f)

# 3. 🛠️ THE FIX: Physically change the 'null' values to 'False'
if config.get("do_crop_margin") is None:
    config["do_crop_margin"] = False
if config.get("do_align_long_axis") is None:
    config["do_align_long_axis"] = False

# Save the patched config back to the hard drive
with open(config_path, "w") as f:
    json.dump(config, f)

print("Config successfully patched! Loading model into GPU...")

# 4. Load the model directly from our patched local directory
processor = NougatProcessor.from_pretrained(local_dir)
model = VisionEncoderDecoderModel.from_pretrained(
    local_dir,
    torch_dtype=torch.float16
).to("cuda")
model.eval()

print("✅ Nougat Loaded Successfully!")

# %%
from PIL import Image
import numpy as np

def nougat_legal_ocr(image):
    if isinstance(image, np.ndarray):
        image = Image.fromarray(image)

    if image.mode != "RGB":
        image = image.convert("RGB")

    # Image preprocessing (with our strict validator bypasses)
    pixel_values = processor(
        image,
        return_tensors="pt",
        do_crop_margin=False,
        do_align_long_axis=False,
        do_thumbnail=False
    ).pixel_values.to("cuda", torch.float16)

    with torch.no_grad():
        outputs = model.generate(
            pixel_values,
            min_length=1,
            max_new_tokens=2048,
            bad_words_ids=[[processor.tokenizer.unk_token_id]],
        )

    # Decode the predicted tokens into text
    sequence = processor.batch_decode(outputs, skip_special_tokens=True)[0]

    # 🛠️ THE FIX: We simply removed the broken processor.post_process_generation() line.
    # The sequence is already decoded into perfectly readable Markdown text!

    return sequence.strip()

# %%
print("\nEvaluating Nougat on Scanned Legal Documents...")
df_nougat = benchmark_legal(ds_legal, nougat_legal_ocr, "Nougat Legal", samples=50)
# Out:
# Evaluating Nougat on Scanned Legal Documents...
#
# ===== Nougat Legal (Legal OCR) =====
# Mean CER: 4.128112005206929
# Mean WER: 4.596226841302843
# Avg Word Count Deviation: 527.56
# Avg Time: 18.9570294713974

# %% [markdown]
# MinerU(Magic Pdf) Pipeline

# %%
# !pip install -q magic-pdf[full]

# %%
import os
import glob
import subprocess
import tempfile
from PIL import Image
import numpy as np

def mineru_legal_ocr(image):
    # 1. Convert PIL Image to RGB
    if isinstance(image, np.ndarray):
        image = Image.fromarray(image)
    if image.mode != "RGB":
        image = image.convert("RGB")

    # 2. Create a temporary directory for MinerU to work in
    with tempfile.TemporaryDirectory() as temp_dir:
        pdf_path = os.path.join(temp_dir, "temp_doc.pdf")
        output_dir = os.path.join(temp_dir, "mineru_output")

        # 3. Save the image as a PDF (MinerU's required input format)
        image.save(pdf_path, "PDF", resolution=100.0)

        # 4. Trigger the MinerU pipeline via CLI
        # -p: input pdf
        # -o: output directory
        # -m: method (forcing 'ocr' mode since these are scanned images)
        command = [
            "magic-pdf",
            "-p", pdf_path,
            "-o", output_dir,
            "-m", "ocr"
        ]

        # Run the pipeline and suppress the massive console output
        subprocess.run(command, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

        # 5. MinerU creates a subfolder inside output_dir. Find the .md file.
        md_files = glob.glob(f"{output_dir}/**/*.md", recursive=True)

        if not md_files:
            return "" # Fallback if the pipeline crashes on a complex page

        # 6. Read and return the extracted Markdown text
        with open(md_files[0], "r", encoding="utf-8") as f:
            extracted_text = f.read()

    return extracted_text.strip()

# ==========================================
# Run the Benchmark!
# ==========================================
print("\nEvaluating MinerU (Magic-PDF) on Scanned Legal Documents...")
df_mineru = benchmark_legal(ds_legal, mineru_legal_ocr, "MinerU Legal", samples=50)
# Out:
# Evaluating MinerU (Magic-PDF) on Scanned Legal Documents...
#
# ===== MinerU Legal (Legal OCR) =====
# Mean CER: 1.0
# Mean WER: 1.0
# Avg Word Count Deviation: 154.04
# Avg Time: 3.6424819946289064
